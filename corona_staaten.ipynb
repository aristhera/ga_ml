# %%
import csv
import matplotlib.pyplot as plt
filename = '/home/gebhard/Dropbox/s1info/weitz/Notebooks/corona.csv'
with open(filename) as corona:
    reader = csv.reader(corona, delimiter=',')
    header_row = next(reader)
    for index, column_header in enumerate(header_row):
        print(index, column_header)
    staat, faelle = [], []
    for row in reader:
        staat.append(row[1])
        faelle.append(row[2])
        staat=sorted(staat)
        faelle=sorted(faelle)
        result=dict(zip(staat, faelle))
    print(result)
# Out:
# 0 Land
# 1 Staat
# 2 Bestä&shy;tigte Fälle
# 3 Neu
# 4 Todes&shy;fälle
# 5 Verdopp&shy;lung
# 6 Trend
# 7 Doubling_Color
# {'': '', ':NA: NA': '10284', ':at: Österreich': '11278', ':au: Australien': '11281', ':be: Belgien': '12051', ':br: Brasilien': '128948', ':ca: Kanada': '131646', ':ch: Schweiz': '15940', ':cn: China': '17965', ':cz: Tschechische Republik': '19691', ':de: Deutschland': '21100', ':dk: Dänemark': '27069', ':es: Spanien': '337646', ':fr: Frankreich': '4563', ':gb: Großbritannien': '4591', ':ie: Irland': '48440', ':il: Israel': '4994', ':ir: Iran': '5389', ':it: Italien': '5687', ':kr: Südkorea': '5759', ':nl: Niederlande': '58226', ':no: Norwegen': '6830', ':pt: Portugal': '82641', ':ru: Russische Föderation': '8611', ':se: Schweden': '93780', ':tr: Türkei': '96786', ':us: Vereinigte Staaten': 'NA'}

# %%
fig = plt.figure(dpi=128, figsize=(10, 6))
plt.plot(list(result.keys()), list(result.values()))

plt.title("Corona Wachstumsraten", fontsize=16)
plt.xlabel('Staat', fontsize=8)

fig.autofmt_xdate()
plt.ylabel("Bestätigte Fälle", fontsize=8)
plt.tick_params(axis='both', which='major')

plt.show()
