# %%
from collections import defaultdict
result=defaultdict(int)
def zyklen(z):
    summe=0
    crn=1
    for i in range(1,z):
        crn=crn*2
        if crn<1000000:
            result[i]+=crn
    return result
print(zyklen(100))



import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')
result
plt.plot(list(result.keys()), list(result.values()), color="blue")
achse = plt.gca()
plt.ylabel("Infizierte", color="red")
plt.xlabel("Tage", color="red")
plt.title("Corona Krise", color="red")
plt.show()
# Out:
# defaultdict(<class 'int'>, {1: 2, 2: 4, 3: 8, 4: 16, 5: 32, 6: 64, 7: 128, 8: 256, 9: 512, 10: 1024, 11: 2048, 12: 4096, 13: 8192, 14: 16384, 15: 32768, 16: 65536, 17: 131072, 18: 262144, 19: 524288})
