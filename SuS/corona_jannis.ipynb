# %%
x=1 # 1 infizierter

# %%
double=9.1 # verdopplung von sz.de 6.4 18uhr

# %%
dictionary={}

# %%
day=1

# %%
while x < 7000000000:
#while x < 10:
    x=(2**(1.00/double))**day
    dictionary.update({day: x})
    day+=1

# %%
print(dictionary)
# Out:
# {1: 1.0791460347989315, 2: 1.1645561644222566, 3: 1.2567261671369305, 4: 1.3561910600938778, 5: 1.4635282049300677, 6: 1.5793606591666804, 7: 1.7043607928571498, 8: 1.8392541914785563, 9: 1.9848238677213987, 10: 2.141914806625826, 11: 2.3114388704473803, 12: 2.4943800917234116, 13: 2.6918003852647145, 14: 2.904845712228653, 15: 3.1347527320542286, 16: 3.382855980871438, 17: 3.650595618053262, 18: 3.939525785876532, 19: 4.251323630816804, 20: 4.587799038842951, 21: 4.950905141221718, 22: 5.342749651815062, 23: 5.765607101679596, 24: 6.221932041986095, 25: 6.714373291897713, 26: 7.245789314111265, 27: 7.819264807311641, 28: 8.43812861185319, 29: 9.10597303260478, 30: 9.826674691121449, 31: 10.604417028182727, 32: 11.443714587317658, 33: 12.34943922027454, 34: 13.326848366549678, 35: 14.381615571128702, 36: 15.519863417586109, 37: 16.74819906770904, 38: 18.073752613941373, 39: 19.504218467271656, 40: 21.0479000208083, 41: 22.713757848299622, 42: 24.51146171737565, 43: 26.451446719431736
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(list(dictionary.keys()), list(dictionary.values()))
plt.ylabel("Kranke")
plt.xlabel("Tage")
plt.title("Entwicklung Corona")
plt.show()

# %% [markdown]
# Wenn Deutschland so weiter macht, haben wir in ~300 Tagen die Welt infiziert :)
